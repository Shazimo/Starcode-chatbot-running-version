# %% [markdown]
# # Bedingungen 🌳
#
# Nach dem wir gelernt haben mit Texten umzugehen, ist es Zeit mit der Information, die man bekommt, was anzufangen! 🎉
#
# Ein wichtiger Aspekt beim Chatbot ist es, durch Bedingungen verschiedene Entscheidungen zu treffen.

# %% [markdown]
# Wir greifen einen Codeausschnitt der Textübungen auf. Jetzt wollen wir nicht nur den Namen des Geburtstagskind wissen, sondern auch, wie alt es ist. Dafür fügen wir eine neue Variable `alter` hinzu!

# %% [markdown]
#  <font color='orange'>***Aufgabe a)*** <br>
#   Führe einmal den folgenden Codeblock aus und gebe deinen Namen und dein Alter ein.</font>

# %%
name = input("Wie heißt das Geburtstagskind?")
alter = input("Wie alt ist das Geburtstagskind?")
# Out:
# Wie heißt das Geburtstagskind? simon
# Wie alt ist das Geburtstagskind? 22

# %% [markdown]
# Wir haben bisher nur mit Texten gearbeitet. Die Variable `alter` ist, obwohl wir eine Zahl eingeben, immer noch ein Text in Anführungszeichen wie die Variable `name`. Mit einem Text können wir allerdings keine Rechenoperationen durchführen. Wir würden also z.B. mit einem Pluszeichen, keine Addition der Zahlen, sondern nur ein Aneinanderhängen der Zahlen erreichen.
#
# Die Frage ist, wie kann man das Alter des Geburtstagskind in eine Zahl verwandeln?
#
# Das geht sehr einfach! <font color=#EA5C19>"**int**"</font>, kurz für integer, bedeutet auf Englisch ganze Zahl.

# %%
print(alter)
alter = int(alter)
print(alter)
# Out:
# 22
# 22

# %% [markdown]
# <font color='orange'>***Aufgabe a)*** <br>
#   Schreibe ein Programm, das text1 und text2 zu Zahlen macht, damit sie addiert werden können.</font>

# %%
text1= input("Gib eine Zahl ein")
text2= input("Gib eine weitere Zahl ein")

#Code hier einfügen
zahl1= #text1 als Zahl
zahl2= #text2 als Zahl
#Ab hier nicht mehr

summe= zahl1 +zahl2
print("Die Summe der Zahlen ist: ", summe)
# Out:
# Gib eine Zahl ein 2
# Gib eine weitere Zahl ein 3
# Die Summe der Zahlen ist:  23

# %% [markdown]
# Wir wollen jetzt wissen, ob das Geburtstagskind ein Kind ist (Alter 0-12 Jahre) 👧🏽. Um das herauszufinden brauchen wir die Einführung der Bedingung des Alters.   Das schafft man durch <font color=#EA5C19>"if-else"</font>.
#
#
# if (Bedingung ist erfüllt):
#
# *  dieser Code wird ausgeführt
#
# else:
#
# *  dieser Code wird ausgeführt
#
#
#
# Das heißt, ist die Bedingung erfüllt, wird unser Chatbot den Code des if-statements ausführen und ansonsten den anderen (else). In Code sieht das dann so aus:

# %%
alter = input("Wie alt ist das Geburtstagskind?")
alter = int(alter)
if alter < 13:
  print("Das Geburtstagskind ist ein Kind!")
else:
  print("Das Geburtstagskind ist kein Kind!")
# Out:
# Wie alt ist das Geburtstagskind?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 alter = input("Wie alt ist das Geburtstagskind?")
# ----> 2 alter = int(alter)
#       3 if alter < 13:
#       4   print("Das Geburtstagskind ist ein Kind!")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
#  <font color='orange'>***Aufgabe b)*** <br>
#   Führe die obigen Codeblöcke für verschiedene Alterseingaben aus und schaue, was ausgegeben wird!</font>

# %% [markdown]
#  <font color='orange'>***Aufgabe c)*** <br>
#   Probiere, das else-statement im letzten Codeblock wegzulassen. Was fällt dir auf?</font>

# %%
# Dein Code hier

# %% [markdown]
# Genau! Das else-statement ist optional! Unser Code läuft auch wenn es kein else-statement gibt.

# %% [markdown]
# <font color='orange'>***Aufgabe d)*** <br>
#   Schreibe ein Programm, das nach dem Alter einer Person fragt und ausgibt, ob die Person volljährig ist oder nicht.
#
#   *Tipp: Du kannst dich an den drei obigen Codeblöcken orientieren.*</font>

# %%
# Dein Code hier

# %% [markdown]
# <font color='orange'>***Aufgabe e)*** <br>
#   Schreibe ein Programm, das nach der Körpergröße (in cm) einer Person fragt und ausgibt, ob die Person größer ist als du oder kleiner.
#   </font>

# %%
# Dein Code hier

# %% [markdown]
# <font color='orange'>***Aufgabe f)*** <br>
#   Schreibe ein Programm, das nach der Klassenstufe fragt und bei 1-6 ausgibt "Du gehst zur Grundschule" und sonst "Du bist an einer weiterführenden Schule".
#   </font>

# %%
# Dein Code hier

# %% [markdown]
# Es gibt nicht nur if-else, sondern auch elif. <font color=#EA5C19>"elif"</font> ist eine Kombination aus "else-if".   Das heißt: Wenn die Bedingung im if-statement nicht erfüllt wurde, schaut das Programm nach, ob die Bedingung im elif-statement erfüllt wird und wenn die nicht erfüllt wird ,schaut es im else-statement nach, falls eins vorhanden ist.
#
# if (Bedingung ist erfüllt):
#
# * dieser Code wird ausgeführt
#
# elif (Bedingung ist erfüllt):
#
# * dieser Code wird ausgeführt
#
# else:
#
# * dieser Code wird ausgeführt
#
#
# <br>
#
# <font color='orange'>***Aufgabe g)***<br>  Schreibe ein Programm, das wiedergibt, ob das Geburtstagskind ein Kind (0-12 Jahre) 👧🏽, Jugendlicher (13-19 Jahre) 👩🏻‍🦰 oder Erwachsener (ab 20 Jahren)  👩🏾‍🦳 ist. Ersetze dafür im folgenden Codeblock die Unterstriche mit den richtigen Bedingungen!
#
# *Tipp: Für Jugendliche könnt ihr zwei Bedingungen verwenden, die mit einem und --and-- verbunden sind, d.h. `alter > 12 and alter < 20`.*</font>

# %%
if _:
  print("Das Geburtstagskind ist ein Kind!")
elif _:
  print("Das Geburtstagskind ist ein Jugendlicher")
else:
  print("Das Geburtstagskind ist ein Erwachsener")

# %% [markdown]
# <font color='orange'>***Aufgabe h)*** <br>
#   Schreibe ein Programm, das nach der Körpergröße fragt und ausgibt, ob sie größer, kleiner viel größer oder viel kleiner sind als du. Viel größer heißt hier mindestens 20 cm größer bzw. kleiner.
#   </font>

# %%
#Dein Code hier

# %%
<font color='orange'>***Aufgabe i)*** <br>
  Schreibe ein Programm, das nach der Klassenstufe fragt und bei 1-4 ausgibt "Du gehst zur Grundschule", bei 5-6 "Es ist nicht klar, an welche Schule du gehst" (denn manche beenden ihre Grundschule nach 4, andere nach 6 Jahren) und sonst "Du bist an einer weiterführenden Schule". o
  </font>

# %%
#Dein Code hier

# %% [markdown]
# Nun wollen wir den Namen und Alter von einer weiteren Person wissen.

# %%
name_person1 = input('Wie heißt das erste Geburtstagskind?')
alter_person1 = input("Wie alt ist das erste Geburtstagskind?")

name_person2 = input('Wie heißt das zweite Geburtstagskind?')
alter_person2 = input("Wie alt ist das zweite Geburtstagskind?")

# %% [markdown]
# <font color='orange'>***Aufgabe j)***<br>  Schreibe ein Programm, dass überprüft, ob die Personen gleich alt sind oder nicht.
#
# *Tipp: Möchtest du herausfinden, ob zwei Objekte gleich sind, musst du ein doppeltes Gleichzeichen `==` benutzen. Sonst geht der Computer davon aus, dass du eine neue Variable definieren willst.*</font>

# %%
# Dein Code hier

# %% [markdown]
# Jetzt wollen wir wissen, welches Geburtstagskind das ältere ist, oder ob sie gleich alt sind!
#
#
# <font color='orange'>***Aufgabe k)***<br>  Schreibe ein Programm, das dies herausfindet! Ersetze hierfür wieder die Unterstriche mit den richtigen Bedingungen.</font>

# %%
# Was sind hier die richtigen Bedingungen?
if _:
  print(name_person2 + " ist älter als " + name_person1)
elif _:
  print(name_person1 + " ist älter als " + name_person2)
else:
  print(name_person1 + " und " + name_person2 + " sind gleich alt!")

# %% [markdown]
# Sehr schön! Jetzt wollen wir noch ein bisschen Farbe ins Spiel bringen. 🎨
#
#  <font color='orange'>***Aufgabe l)***<br>  Schreibe ein Programm, das eine Eingabe-Farbe mit Blau mischt, indem du wieder die richtigen Bedingungen einsetzt.</font>

# %%
mischfarbe = input('Welche Farbe willst du mit Blau mischen?')

# Welche Farbe gemischt mit Blau ergibt Grün?
if _:
  print("Grün")
# Welche Farbe gemischt mit Blau ergibt Violett?
elif _:
  print("Violett")
# alle anderen Farben
else:
  print("Keine bekannte Farbmischung")

# %% [markdown]
# Fantastisch 🥳
